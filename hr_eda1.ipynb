# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None) 
data = pd.read_excel("C:\\Users\\HUAWEI\\Desktop\\project\\hr analysis\\HR Data.xlsx")
data.head()
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
#   Marital Status Over Time Over18  Training Times Last Year  Age  \
# ...

# %%
data.columns
# Out:
# Index(['Attrition', 'Business Travel', 'CF_age band', 'CF_attrition label',
#        'Department', 'Education Field', 'emp no', 'Employee Number', 'Gender',
#        'Job Role', 'Marital Status', 'Over Time', 'Over18',
#        'Training Times Last Year', 'Age', 'CF_current Employee', 'Daily Rate',
#        'Distance From Home', 'Education', 'Employee Count',
#        'Environment Satisfaction', 'Hourly Rate', 'Job Involvement',
#        'Job Level', 'Job Satisfaction', 'Monthly Income', 'Monthly Rate',
#        'Num Companies Worked', 'Percent Salary Hike', 'Performance Rating',
#        'Relationship Satisfaction', 'Standard Hours', 'Stock Option Level',
#        'Total Working Years', 'Work Life Balance', 'Years At Company',
#        'Years In Current Role', 'Years Since Last Promotion',
#        'Years With Curr Manager'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Attrition                     object
# Business Travel               object
# CF_age band                   object
# CF_attrition label            object
# Department                    object
# Education Field               object
# emp no                        object
# Employee Number                int64
# Gender                        object
# Job Role                      object
# Marital Status                object
# Over Time                     object
# Over18                        object
# Training Times Last Year       int64
# Age                            int64
# CF_current Employee            int64
# Daily Rate                     int64
# Distance From Home             int64
# Education                     object
# Employee Count                 int64
# Environment Satisfaction       int64
# Hourly Rate                    int64
# Job Involvement                int64
# Job Level                      int64
# Job Satisfaction               int64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Attrition                   1470 non-null   object
#  1   Business Travel             1470 non-null   object
#  2   CF_age band                 1470 non-null   object
#  3   CF_attrition label          1470 non-null   object
#  4   Department                  1470 non-null   object
#  5   Education Field             1470 non-null   object
#  6   emp no                      1470 non-null   object
#  7   Employee Number             1470 non-null   int64
#  8   Gender                      1470 non-null   object
#  9   Job Role                    1470 non-null   object
#  10  Marital Status              1470 non-null   object
#  11  Over Time                   1470 non-null   object
#  12  Over18                      1470 non-null   object
# ...

# %%
data.isnull()
# Out:
#       Attrition  Business Travel  CF_age band  CF_attrition label  Department  \
# 0         False            False        False               False       False
# 1         False            False        False               False       False
# 2         False            False        False               False       False
# 3         False            False        False               False       False
# 4         False            False        False               False       False
# ...         ...              ...          ...                 ...         ...
# 1465      False            False        False               False       False
# 1466      False            False        False               False       False
# 1467      False            False        False               False       False
# 1468      False            False        False               False       False
# 1469      False            False        False               False       False
#
# ...

# %%
#checking for null values
data.isnull().sum()
# Out:
# Attrition                     0
# Business Travel               0
# CF_age band                   0
# CF_attrition label            0
# Department                    0
# Education Field               0
# emp no                        0
# Employee Number               0
# Gender                        0
# Job Role                      0
# Marital Status                0
# Over Time                     0
# Over18                        0
# Training Times Last Year      0
# Age                           0
# CF_current Employee           0
# Daily Rate                    0
# Distance From Home            0
# Education                     0
# Employee Count                0
# Environment Satisfaction      0
# Hourly Rate                   0
# Job Involvement               0
# Job Level                     0
# Job Satisfaction              0
# Monthly Income                0
# Monthly Rate                  0
# Num Companies Worked          0
# Percent Salary Hike           0
# ...

# %%
data.describe()
# Out:
#        Employee Number  Training Times Last Year          Age  \
# count      1470.000000               1470.000000  1470.000000
# mean       1024.865306                  2.799320    36.923810
# std         602.024335                  1.289271     9.135373
# min           1.000000                  0.000000    18.000000
# 25%         491.250000                  2.000000    30.000000
# 50%        1020.500000                  3.000000    36.000000
# 75%        1555.750000                  3.000000    43.000000
# max        2068.000000                  6.000000    60.000000
#
#        CF_current Employee   Daily Rate  Distance From Home  Employee Count  \
# count          1470.000000  1470.000000         1470.000000          1470.0
# mean              0.838776   802.485714            9.192517             1.0
# std               0.367863   403.509100            8.106864             0.0
# min               0.000000   102.000000            1.000000             1.0
# ...

# %%
data.Over18.unique()
# Out:
# array(['Y'], dtype=object)

# %%
#Since all values are presumably "Y" (indicating all employees are over 18), this column doesn't provide any useful information and can be removed.
data.drop(columns=['Over18'], inplace=True)

# %%
#emp no and Employee Number: These columns seems to represent the same information, but in different formats
#(emp no is an object and Employee Number is an integer). so can remove emp no.
data.drop(columns=['emp no'], inplace=True)

# %%
data['Employee Count'].unique()
# Out:
# array([1], dtype=int64)

# %%
#If all values are the same, this column doesn't provide any useful information and can be removed.
data.drop(columns=['Employee Count'], inplace=True)

# %%
pd.set_option('display.max_columns', None) 
data.head(7)
# Out:
#      Business Travel Department Education Field  Employee Number  Gender  \
# 0      Travel_Rarely      Sales   Life Sciences                1  Female
# 1  Travel_Frequently        R&D   Life Sciences                2    Male
# 2      Travel_Rarely        R&D           Other                4    Male
# 3  Travel_Frequently        R&D   Life Sciences                5  Female
# 4      Travel_Rarely        R&D         Medical                7    Male
# 5  Travel_Frequently        R&D   Life Sciences                8    Male
# 6      Travel_Rarely        R&D         Medical               10  Female
#
#                 Job Role Marital Status Over Time  Training Times Last Year  \
# 0        Sales Executive         Single       Yes                         0
# 1     Research Scientist        Married        No                         3
# 2  Laboratory Technician         Single       Yes                         3
# 3     Research Scientist        Married       Yes                         3
# ...

# %%
data['Environment Satisfaction'].unique()
# Out:
# array([2, 3, 4, 1], dtype=int64)

# %%
#CF_attrition label and CF_current Employee: These columns seems to represent the same information, so can remove on of it
data.drop(columns=['CF_attrition label'], inplace=True)

# %%
data['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
#attrition and CF_current Employee: These columns seems to represent the same information, so can remove on of it
data.drop(columns=['Attrition'], inplace=True)

# %%
#CF_age band and Age: These columns seems to represent the same information, so can remove on of it
data.drop(columns=['CF_age band'], inplace=True)

# %%
data['Standard Hours'].unique()
# Out:
# array([80], dtype=int64)

# %%
#If all values are the same, this column doesn't provide any useful information and can be removed.
data.drop(columns=['Standard Hours'], inplace=True)

# %%
data.tail(7)
# Out:
#         Business Travel Department   Education Field  Employee Number  Gender  \
# 1463      Travel_Rarely      Sales           Medical             1489  Female
# 1464      Travel_Rarely      Sales     Life Sciences             1758  Female
# 1465         Non-Travel        R&D  Technical Degree             1905    Male
# 1466  Travel_Frequently        R&D     Life Sciences             1868    Male
# 1467  Travel_Frequently      Sales             Other             1667    Male
# 1468      Travel_Rarely        R&D     Life Sciences             1878    Male
# 1469      Travel_Rarely      Sales     Life Sciences             1702    Male
#
#                   Job Role Marital Status Over Time  Training Times Last Year  \
# 1463       Sales Executive         Single       Yes                         2
# 1464       Sales Executive         Single       Yes                         2
# 1465    Research Scientist        Married       Yes                         2
# ...

# %%
data["Performance Rating"].unique()
# Out:
# array([3, 4], dtype=int64)

# %%
data['Department'].unique()
# Out:
# array(['Sales', 'R&D', 'HR'], dtype=object)

# %%
data['Department'].mode()
# Out:
# 0    R&D
# Name: Department, dtype: object

# %%
#Average salary of each of the department
average_salary= data.groupby('Department')['Monthly Income'].mean()
average_salary
# Out:
# Department
# HR       6654.507937
# R&D      6281.252862
# Sales    6959.172646
# Name: Monthly Income, dtype: float64

# %%
data.groupby('Department')['Monthly Income'].mean().plot.bar()
# Out:
# <Axes: xlabel='Department'>

# %%
#Average salary by Education
average_salary= data.groupby('Education')['Monthly Income'].mean()
average_salary
# Out:
# Education
# Associates Degree    6226.645390
# Bachelor's Degree    6517.263986
# Doctoral Degree      8277.645833
# High School          5640.570588
# Master's Degree      6832.402010
# Name: Monthly Income, dtype: float64

# %%
data.loc[:, 'Business Travel':'Monthly Rate']
# Out:
#         Business Travel Department   Education Field  Employee Number  Gender  \
# 0         Travel_Rarely      Sales     Life Sciences                1  Female
# 1     Travel_Frequently        R&D     Life Sciences                2    Male
# 2         Travel_Rarely        R&D             Other                4    Male
# 3     Travel_Frequently        R&D     Life Sciences                5  Female
# 4         Travel_Rarely        R&D           Medical                7    Male
# ...                 ...        ...               ...              ...     ...
# 1465         Non-Travel        R&D  Technical Degree             1905    Male
# 1466  Travel_Frequently        R&D     Life Sciences             1868    Male
# 1467  Travel_Frequently      Sales             Other             1667    Male
# 1468      Travel_Rarely        R&D     Life Sciences             1878    Male
# 1469      Travel_Rarely      Sales     Life Sciences             1702    Male
#
# ...

# %%
data.sort_values("Monthly Income",axis=0,ascending=False)
# Out:
#         Business Travel Department   Education Field  Employee Number  Gender  \
# 190       Travel_Rarely        R&D     Life Sciences              259    Male
# 746          Non-Travel        R&D     Life Sciences             1035  Female
# 851       Travel_Rarely        R&D  Technical Degree             1191  Female
# 165       Travel_Rarely        R&D     Life Sciences              226  Female
# 568       Travel_Rarely        R&D           Medical              787    Male
# ...                 ...        ...               ...              ...     ...
# 1416  Travel_Frequently      Sales  Technical Degree             1928    Male
# 1434      Travel_Rarely      Sales           Medical             1876    Male
# 764       Travel_Rarely      Sales           Medical             1056    Male
# 727          Non-Travel        R&D     Life Sciences             1012    Male
# 513       Travel_Rarely        R&D           Medical              701    Male
#
# ...

# %%
data.sort_values("Age",axis=0,ascending=True)
# Out:
#         Business Travel Department Education Field  Employee Number  Gender  \
# 727          Non-Travel        R&D   Life Sciences             1012    Male
# 972          Non-Travel        R&D   Life Sciences             1368  Female
# 296       Travel_Rarely        R&D   Life Sciences              405    Male
# 1004         Non-Travel        R&D         Medical             1839  Female
# 301       Travel_Rarely      Sales         Medical              411  Female
# ...                 ...        ...             ...              ...     ...
# 427   Travel_Frequently      Sales       Marketing              573  Female
# 411       Travel_Rarely        R&D   Life Sciences              549  Female
# 879       Travel_Rarely      Sales       Marketing             1233    Male
# 1369      Travel_Rarely        R&D         Medical             1697    Male
# 536       Travel_Rarely      Sales       Marketing              732    Male
#
# ...

# %%
#Checking for inconsistent values
data["Education Field"].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
data["Job Role"].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
data['Business Travel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
data['Education'].unique()
# Out:
# array(['Associates Degree', 'High School', "Master's Degree",
#        "Bachelor's Degree", 'Doctoral Degree'], dtype=object)

# %%
data.head(3)
# Out:
#      Business Travel Department Education Field  Employee Number  Gender  \
# 0      Travel_Rarely      Sales   Life Sciences                1  Female
# 1  Travel_Frequently        R&D   Life Sciences                2    Male
# 2      Travel_Rarely        R&D           Other                4    Male
#
#                 Job Role Marital Status Over Time  Training Times Last Year  \
# 0        Sales Executive         Single       Yes                         0
# 1     Research Scientist        Married        No                         3
# 2  Laboratory Technician         Single       Yes                         3
#
#    Age  CF_current Employee  Daily Rate  Distance From Home  \
# 0   41                    0        1102                   1
# 1   49                    1         279                   8
# 2   37                    0        1373                   2
#
#            Education  Environment Satisfaction  Hourly Rate  Job Involvement  \
# ...

# %%
data.columns
# Out:
# Index(['Business Travel', 'Department', 'Education Field', 'Employee Number',
#        'Gender', 'Job Role', 'Marital Status', 'Over Time',
#        'Training Times Last Year', 'Age', 'CF_current Employee', 'Daily Rate',
#        'Distance From Home', 'Education', 'Environment Satisfaction',
#        'Hourly Rate', 'Job Involvement', 'Job Level', 'Job Satisfaction',
#        'Monthly Income', 'Monthly Rate', 'Num Companies Worked',
#        'Percent Salary Hike', 'Performance Rating',
#        'Relationship Satisfaction', 'Stock Option Level',
#        'Total Working Years', 'Work Life Balance', 'Years At Company',
#        'Years In Current Role', 'Years Since Last Promotion',
#        'Years With Curr Manager'],
#       dtype='object')

# %%
#checking for duplicate value
data.duplicated().sum()
# Out:
# 0

# %%
#checking for null values
data.isnull().mean()
# Out:
# Business Travel               0.0
# Department                    0.0
# Education Field               0.0
# Employee Number               0.0
# Gender                        0.0
# Job Role                      0.0
# Marital Status                0.0
# Over Time                     0.0
# Training Times Last Year      0.0
# Age                           0.0
# CF_current Employee           0.0
# Daily Rate                    0.0
# Distance From Home            0.0
# Education                     0.0
# Environment Satisfaction      0.0
# Hourly Rate                   0.0
# Job Involvement               0.0
# Job Level                     0.0
# Job Satisfaction              0.0
# Monthly Income                0.0
# Monthly Rate                  0.0
# Num Companies Worked          0.0
# Percent Salary Hike           0.0
# Performance Rating            0.0
# Relationship Satisfaction     0.0
# Stock Option Level            0.0
# Total Working Years           0.0
# ...

# %%
data.to_excel("HR Data2.xlsx")
